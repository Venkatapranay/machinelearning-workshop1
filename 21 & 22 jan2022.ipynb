# %% [markdown]
# ## data cleaning and manipulation

# %% [markdown]
# ### identifying duplicates and null values using pandas

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/nagamounika5/Datasets/master/Global%20Dataset/Market_Fact.csv')

# %%
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
# duplicate finding
dict={'students':['harika','harika','lasya','sairam','sairam'],
      'sports':['football','football','badminton','hockey','hockey'],
       'rank':['state','state','international','district','district']}
data=pd.DataFrame(dict)
data
# Out:
#   students     sports           rank
# 0   harika   football          state
# 1   harika   football          state
# 2    lasya  badminton  international
# 3   sairam     hockey       district
# 4   sairam     hockey       district

# %%
data.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
data[data.duplicated()]
# Out:
#   students    sports      rank
# 1   harika  football     state
# 4   sairam    hockey  district

# %%
# remove duplicate values
# dataframe.drop_duplicates()
data.drop_duplicates()
# Out:
#   students     sports           rank
# 0   harika   football          state
# 2    lasya  badminton  international
# 3   sairam     hockey       district

# %%
data
# Out:
#   students     sports           rank
# 0   harika   football          state
# 1   harika   football          state
# 2    lasya  badminton  international
# 3   sairam     hockey       district
# 4   sairam     hockey       district

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#   students     sports           rank
# 0   harika   football          state
# 2    lasya  badminton  international
# 3   sairam     hockey       district

# %% [markdown]
# ## inplace=true >original changes
# ## else original remains same

# %% [markdown]
# ## identyfy null value
#      - isnull()
#      - notnull()

# %%
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df.isnull()
# Out:
#       Ord_id  Prod_id  Ship_id  Cust_id  Sales  Discount  Order_Quantity  \
# 0      False    False    False    False  False     False           False
# 1      False    False    False    False  False     False           False
# 2      False    False    False    False  False     False           False
# 3      False    False    False    False  False     False           False
# 4      False    False    False    False  False     False           False
# ...      ...      ...      ...      ...    ...       ...             ...
# 8394   False    False    False    False  False     False           False
# 8395   False    False    False    False  False     False           False
# 8396   False    False    False    False  False     False           False
# 8397   False    False    False    False  False     False           False
# 8398   False    False    False    False  False     False           False
#
#       Profit  Shipping_Cost  Product_Base_Margin
# ...

# %%
df.isnull()
# Out:
#       Ord_id  Prod_id  Ship_id  Cust_id  Sales  Discount  Order_Quantity  \
# 0      False    False    False    False  False     False           False
# 1      False    False    False    False  False     False           False
# 2      False    False    False    False  False     False           False
# 3      False    False    False    False  False     False           False
# 4      False    False    False    False  False     False           False
# ...      ...      ...      ...      ...    ...       ...             ...
# 8394   False    False    False    False  False     False           False
# 8395   False    False    False    False  False     False           False
# 8396   False    False    False    False  False     False           False
# 8397   False    False    False    False  False     False           False
# 8398   False    False    False    False  False     False           False
#
#       Profit  Shipping_Cost  Product_Base_Margin
# ...

# %%
df.isnull().sum()  # returns columnwise null value
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
df[df.isnull()]
# Out:
#      Ord_id Prod_id Ship_id Cust_id  Sales  Discount  Order_Quantity  Profit  \
# 0       NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
# 1       NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
# 2       NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
# 3       NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
# 4       NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
# ...     ...     ...     ...     ...    ...       ...             ...     ...
# 8394    NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
# 8395    NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
# 8396    NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
# 8397    NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
# 8398    NaN     NaN     NaN     NaN    NaN       NaN             NaN     NaN
#
#       Shipping_Cost  Product_Base_Margin
# ...

# %%
df.isnull().sum().sum() # total no of null in dataset
# Out:
# 63

# %%
df['Product_Base_Margin'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# Name: Product_Base_Margin, Length: 8399, dtype: bool

# %%
df[df['Product_Base_Margin'].isnull()]  # rows with null values
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 107    Ord_250  Prod_15   SHP_346    Cust_45   8901.78      0.04
# 276   Ord_4770   Prod_1  SHP_6654  Cust_1652   1128.03      0.01
# 376   Ord_4076   Prod_1  SHP_5683  Cust_1384    740.49      0.10
# 584   Ord_2897  Prod_15  SHP_3998  Cust_1052    897.42      0.08
# 777   Ord_5142  Prod_15  SHP_7183  Cust_1746  10656.26      0.06
# ...        ...      ...       ...        ...       ...       ...
# 7657  Ord_3306  Prod_11  SHP_4586  Cust_1181   9601.94      0.08
# 8022  Ord_2174  Prod_15  SHP_2963   Cust_818   6131.54      0.06
# 8042  Ord_5357  Prod_11  SHP_7483  Cust_1803  14451.75      0.01
# 8367  Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.05      0.09
# 8388  Ord_4424   Prod_1  SHP_6165  Cust_1519    994.04      0.03
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 107               31  2795.36          24.49                  NaN
# ...

# %%
df.dropna(axis=0)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Ord_id                 0
# Prod_id                0
# Ship_id                0
# Cust_id                0
# Sales                  0
# Discount               0
# Order_Quantity         0
# Profit                 0
# Shipping_Cost          0
# Product_Base_Margin    0
# dtype: int64

# %% [markdown]
# **replace null values**
# - fillna()
#
# - if data column is numerical replace with mean( )/median()/0
#
# - if data column is object replace with most frequent value

# %%
df=pd.read_csv('https://raw.githubusercontent.com/nagamounika5/Datasets/master/Global%20Dataset/Market_Fact.csv')
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %%
df['Product_Base_Margin'].mean()
# Out:
# 0.5125131957773527

# %%
df['Product_Base_Margin'].fillna(df['Product_Base_Margin'].mean(),inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (8399, 10)

# %%
df['Product_Base_Margin'].value_counts()
# Out:
# 0.370000    761
# 0.380000    678
# 0.360000    628
# 0.590000    497
# 0.390000    482
# 0.560000    459
# 0.570000    459
# 0.400000    408
# 0.580000    387
# 0.550000    314
# 0.600000    296
# 0.350000    262
# 0.520000    150
# 0.740000    108
# 0.430000    101
# 0.650000    100
# 0.410000     98
# 0.490000     95
# 0.440000     94
# 0.640000     91
# 0.780000     89
# 0.750000     85
# 0.830000     83
# 0.660000     81
# 0.540000     81
# 0.620000     78
# 0.460000     78
# 0.420000     78
# 0.690000     77
# 0.480000     75
# 0.500000     73
# 0.810000     73
# 0.610000     73
# 0.790000     68
# 0.770000     68
# 0.680000     66
# 0.510000     66
# 0.512513     63
# 0.710000     57
# 0.760000     55
# 0.450000     54
# 0.730000     51
# 0.800000     48
# 0.470000     46
# 0.670000     41
# 0.720000     37
# 0.850000     36
# 0.630000     36
# 0.700000     32
# 0.820000     32
# 0.530000     26
# 0.840000     25
# Name: Product_Base_Margin, dtype: int64

# %% [markdown]
# **delete unwanted columns**

# %%
df.drop('Ship_id',axis=1)
# Out:
#         Ord_id  Prod_id    Cust_id      Sales  Discount  Order_Quantity  \
# 0     Ord_5446  Prod_16  Cust_1818   136.8100      0.01              23
# 1     Ord_5406  Prod_13  Cust_1818    42.2700      0.01              13
# 2     Ord_5446   Prod_4  Cust_1818  4701.6900      0.00              26
# 3     Ord_5456   Prod_6  Cust_1818  2337.8900      0.09              43
# 4     Ord_5485  Prod_17  Cust_1818  4233.1500      0.08              35
# ...        ...      ...        ...        ...       ...             ...
# 8394  Ord_5353   Prod_4  Cust_1798  2841.4395      0.08              28
# 8395  Ord_5411   Prod_6  Cust_1798   127.1600      0.10              20
# 8396  Ord_5388   Prod_6  Cust_1798   243.0500      0.02              39
# 8397  Ord_5348  Prod_15  Cust_1798  3872.8700      0.03              23
# 8398  Ord_5459   Prod_6  Cust_1798   603.6900      0.00              47
#
#        Profit  Shipping_Cost  Product_Base_Margin
# 0      -30.51           3.60                 0.56
# ...

# %%
help(df.fillna)
# Out:
# Help on method fillna in module pandas.core.frame:
#
# fillna(value: 'object | ArrayLike | None' = None, method: 'FillnaOptions | None' = None, axis: 'Axis | None' = None, inplace: 'bool' = False, limit=None, downcast=None) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Fill NA/NaN values using the specified method.
#
#     Parameters
#     ----------
#     value : scalar, dict, Series, or DataFrame
#         Value to use to fill holes (e.g. 0), alternately a
#         dict/Series/DataFrame of values specifying which value to use for
#         each index (for a Series) or column (for a DataFrame).  Values not
#         in the dict/Series/DataFrame will not be filled. This value cannot
#         be a list.
#     method : {'backfill', 'bfill', 'pad', 'ffill', None}, default None
#         Method to use for filling holes in reindexed Series
#         pad / ffill: propagate last valid observation forward to next valid
# ...

# %%
import numpy as np
import pandas as pd

# %%
dict1={'students':['lingareddy','uday','pranay','pranay',np.NaN],
        'year':[2,np.NaN,3,4,1],'branch':[np.NaN,'cse','eee','it','mec'],'specialized':['ncc','jee','sports',np.NaN,'ncc']}
data2=pd.DataFrame(dict1)
data2
# Out:
#      students  year branch specialized
# 0  lingareddy   2.0    NaN         ncc
# 1        uday   NaN    cse         jee
# 2      pranay   3.0    eee      sports
# 3      pranay   4.0     it         NaN
# 4         NaN   1.0    mec         ncc

# %%
# dataframe['year'].fillna(method=ffill)

# %% [markdown]
# - replace all null of 'students' column with ffill
#
# - replace all null of 'year' with 0
#
# - replace all null of 'branch with bfill
#
# - replace all null of 'specialized' with most frequent value

# %%
data2['students'].fillna(method='ffill',inplace=True)

# %%
data2['branch'].fillna(method='bfill',inplace=True)

# %%
data2['year'].fillna(0,inplace=True)

# %%
data2['specialized'].value_counts()
# Out:
# ncc       2
# jee       1
# sports    1
# Name: specialized, dtype: int64

# %%
data2['specialized'].fillna('ncc',inplace=True)

# %%
data2
# Out:
#      students  year branch specialized
# 0  lingareddy   2.0    cse         ncc
# 1        uday   0.0    cse         jee
# 2      pranay   3.0    eee      sports
# 3      pranay   4.0     it         ncc
# 4      pranay   1.0    mec         ncc

# %% [markdown]
# ## matplotlib

# %%
import matplotlib as mpl

# %%
from matplotlib import pyplot as plt

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '_IoffContext',
#  '_IonContext',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_code_objs',
# ...

# %% [markdown]
# ### image reading and slicing

# %%
i=plt.imread('dataanalysis.jpg')
i
# Out:
# array([[[ 42,  69, 112],
#         [ 42,  69, 112],
#         [ 43,  70, 115],
#         ...,
#         [  5, 159, 193],
#         [  5, 159, 193],
#         [  5, 159, 193]],
#
#        [[ 44,  68, 116],
#         [ 44,  67, 117],
#         [ 45,  68, 118],
#         ...,
#         [  5, 159, 193],
#         [  5, 159, 193],
#         [  5, 159, 193]],
#
#        [[ 45,  66, 123],
#         [ 45,  66, 123],
#         [ 45,  66, 123],
#         ...,
#         [  5, 159, 193],
#         [  5, 159, 193],
#         [  5, 159, 193]],
#
#        ...,
#
#        [[ 57,  15,  87],
#         [ 75,  33, 105],
#         [ 55,  13,  85],
#         ...,
#         [ 26, 112, 159],
#         [ 26, 112, 159],
#         [ 26, 112, 159]],
#
#        [[ 64,  24,  95],
#         [ 82,  40, 112],
#         [ 62,  20,  92],
#         ...,
#         [ 26, 112, 159],
#         [ 26, 112, 159],
#         [ 26, 112, 159]],
#
#        [[ 74,  34, 105],
#         [ 91,  51, 122],
#         [ 70,  28, 100],
# ...

# %%
plt.imshow(i)
